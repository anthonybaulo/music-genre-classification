# %%
import os
import numpy as np
import librosa
import librosa.display
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from tensorflow.keras.layers import MaxPooling2D, Flatten, Conv1D, \
                                    Conv2D, BatchNormalization, MaxPooling1D, \
                                    GlobalAveragePooling2D
from tensorflow.keras.layers import Lambda, ELU
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # Rock vs Instrumental

# %%
META_DIR = Path('../data/fma_metadata')
AUDIO_DIR = Path('../data/fma_small')
CONVERTED_DIR = Path('../data/converted/rock_inst')

# %%
def show_summary_stats(history, dpi=100):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.figure(figsize=(4,3), dpi=dpi)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()

    # Summarize history for loss
    plt.figure(figsize=(4,3), dpi=dpi)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()

# %%
genre_dict = {'Rock': 0, 'Instrumental': 1}

reverse_map = {v: k for k, v in genre_dict.items()}
print(reverse_map)
# Out:
# {0: 'Rock', 1: 'Instrumental'}

# %%
npzfile = np.load(CONVERTED_DIR/'train_arr.npz')
X_train = npzfile['X']
y_train = npzfile['y']
print(X_train.shape, y_train.shape)
# Out:
# (1599, 640, 128) (1599,)

# %%
npzfile = np.load(CONVERTED_DIR/'valid_arr.npz')
X_valid = npzfile['X']
y_valid = npzfile['y']
print(X_valid.shape, y_valid.shape)
# Out:
# (200, 640, 128) (200,)

# %%
# Add dimension for single channel for Conv2D
X_train = X_train[...,None] / -80
X_valid = X_valid[...,None] / -80

# %%
y_train = to_categorical(y_train)
y_valid = to_categorical(y_valid)

# %%
# Build model
model = Sequential()

model.add(Conv2D(32, (5, 5), input_shape = (640, 128, 1), 
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (1, 1), activation='relu'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))

model.add(Dense(units = 64, activation = 'relu'))
model.add(Dropout(0.3))

model.add(Dense(units = 2, activation = 'softmax'))

opt = Adam(lr=0.0005)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 640, 128, 32)      832
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 320, 64, 32)       0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 320, 64, 32)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 318, 62, 64)       18496
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 318, 62, 128)      8320
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 128)               0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 36,034
# Trainable params: 36,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_callback = ModelCheckpoint('../models/model2_best.h5', monitor='val_accuracy', verbose=1,
                                      save_best_only=True, mode='max')

reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, 
                                      patience=6, min_delta=0.01, verbose=1)

callbacks_list = [checkpoint_callback, reducelr_callback]

# %%
history = model.fit(X_train, y_train, batch_size=128, epochs=50,
                    validation_data=(X_valid, y_valid), verbose=1, 
                    callbacks=callbacks_list)
# Out:
# Train on 1599 samples, validate on 200 samples
# Epoch 1/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6890 - accuracy: 0.4922
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 17s 11ms/sample - loss: 0.6894 - accuracy: 0.4891 - val_loss: 0.6893 - val_accuracy: 0.5000
# Epoch 2/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6762 - accuracy: 0.5039
# Epoch 00002: val_accuracy did not improve from 0.50000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6765 - accuracy: 0.5022 - val_loss: 0.6836 - val_accuracy: 0.5000
# Epoch 3/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6695 - accuracy: 0.5078
# Epoch 00003: val_accuracy improved from 0.50000 to 0.50500, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6693 - accuracy: 0.5078 - val_loss: 0.6763 - val_accuracy: 0.5050
# Epoch 4/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6560 - accuracy: 0.5794
# Epoch 00004: val_accuracy improved from 0.50500 to 0.52000, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6553 - accuracy: 0.5785 - val_loss: 0.6632 - val_accuracy: 0.5200
# Epoch 5/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6272 - accuracy: 0.6549
# Epoch 00005: val_accuracy improved from 0.52000 to 0.73500, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6258 - accuracy: 0.6560 - val_loss: 0.6331 - val_accuracy: 0.7350
# Epoch 6/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.5717 - accuracy: 0.7624
# Epoch 00006: val_accuracy did not improve from 0.73500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.5716 - accuracy: 0.7617 - val_loss: 0.6099 - val_accuracy: 0.7000
# Epoch 7/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.5156 - accuracy: 0.7793
# Epoch 00007: val_accuracy did not improve from 0.73500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.5129 - accuracy: 0.7799 - val_loss: 0.5697 - val_accuracy: 0.7100
# Epoch 8/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4674 - accuracy: 0.7910
# Epoch 00008: val_accuracy improved from 0.73500 to 0.78000, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4664 - accuracy: 0.7924 - val_loss: 0.5383 - val_accuracy: 0.7800
# Epoch 9/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4618 - accuracy: 0.7910
# Epoch 00009: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4636 - accuracy: 0.7892 - val_loss: 0.5497 - val_accuracy: 0.7250
# Epoch 10/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4523 - accuracy: 0.8060
# Epoch 00010: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4491 - accuracy: 0.8074 - val_loss: 0.5747 - val_accuracy: 0.6950
# Epoch 11/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4408 - accuracy: 0.8053
# Epoch 00011: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4377 - accuracy: 0.8068 - val_loss: 0.5444 - val_accuracy: 0.7300
# Epoch 12/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4301 - accuracy: 0.8086
# Epoch 00012: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4314 - accuracy: 0.8086 - val_loss: 0.5273 - val_accuracy: 0.7450
# Epoch 13/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4535 - accuracy: 0.7923
# Epoch 00013: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4538 - accuracy: 0.7924 - val_loss: 0.7145 - val_accuracy: 0.6150
# Epoch 14/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4516 - accuracy: 0.7910
# Epoch 00014: val_accuracy did not improve from 0.78000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4490 - accuracy: 0.7942 - val_loss: 0.5322 - val_accuracy: 0.7300
# Epoch 15/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4418 - accuracy: 0.7969
# Epoch 00015: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4419 - accuracy: 0.7961 - val_loss: 0.5288 - val_accuracy: 0.7250
# Epoch 16/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4368 - accuracy: 0.8066
# Epoch 00016: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4359 - accuracy: 0.8068 - val_loss: 0.6054 - val_accuracy: 0.6800
# Epoch 17/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4380 - accuracy: 0.8027
# Epoch 00017: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4338 - accuracy: 0.8055 - val_loss: 0.5832 - val_accuracy: 0.6950
# Epoch 18/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4307 - accuracy: 0.8053
# Epoch 00018: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4257 - accuracy: 0.8093 - val_loss: 0.5740 - val_accuracy: 0.6950
# Epoch 19/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4307 - accuracy: 0.8027
# Epoch 00019: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4273 - accuracy: 0.8061 - val_loss: 0.5121 - val_accuracy: 0.7400
# Epoch 20/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4275 - accuracy: 0.8047
# Epoch 00020: val_accuracy improved from 0.78000 to 0.80500, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4257 - accuracy: 0.8043 - val_loss: 0.4949 - val_accuracy: 0.8050
# Epoch 21/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4148 - accuracy: 0.8060
# Epoch 00021: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 12s 8ms/sample - loss: 0.4215 - accuracy: 0.8043 - val_loss: 0.5198 - val_accuracy: 0.7250
# Epoch 22/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4248 - accuracy: 0.8053
# Epoch 00022: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4259 - accuracy: 0.8036 - val_loss: 0.6016 - val_accuracy: 0.6800
# Epoch 23/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4323 - accuracy: 0.8125
# Epoch 00023: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4323 - accuracy: 0.8124 - val_loss: 0.5603 - val_accuracy: 0.7200
# Epoch 24/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4301 - accuracy: 0.8073
# Epoch 00024: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4309 - accuracy: 0.8061 - val_loss: 0.5544 - val_accuracy: 0.7150
# Epoch 25/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4480 - accuracy: 0.7878
# Epoch 00025: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4455 - accuracy: 0.7886 - val_loss: 0.4985 - val_accuracy: 0.7550
# Epoch 26/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4241 - accuracy: 0.8008
# Epoch 00026: val_accuracy did not improve from 0.80500
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4272 - accuracy: 0.7986 - val_loss: 0.4940 - val_accuracy: 0.7650
# Epoch 27/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4161 - accuracy: 0.8066
# Epoch 00027: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4228 - accuracy: 0.8043 - val_loss: 0.5476 - val_accuracy: 0.7200
# Epoch 28/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4178 - accuracy: 0.8138
# Epoch 00028: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4190 - accuracy: 0.8105 - val_loss: 0.5005 - val_accuracy: 0.7400
# Epoch 29/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4197 - accuracy: 0.8040
# Epoch 00029: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4209 - accuracy: 0.8049 - val_loss: 0.5068 - val_accuracy: 0.7300
# Epoch 30/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4184 - accuracy: 0.8125
# Epoch 00030: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4210 - accuracy: 0.8130 - val_loss: 0.5273 - val_accuracy: 0.7250
# Epoch 31/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4192 - accuracy: 0.8105
# Epoch 00031: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4204 - accuracy: 0.8099 - val_loss: 0.5128 - val_accuracy: 0.7250
# Epoch 32/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4066 - accuracy: 0.8177
# Epoch 00032: val_accuracy did not improve from 0.80500
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4082 - accuracy: 0.8155 - val_loss: 0.4972 - val_accuracy: 0.7400
# Epoch 33/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4127 - accuracy: 0.8125
# Epoch 00033: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4133 - accuracy: 0.8118 - val_loss: 0.5129 - val_accuracy: 0.7200
# Epoch 34/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4159 - accuracy: 0.8112
# Epoch 00034: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4161 - accuracy: 0.8099 - val_loss: 0.5039 - val_accuracy: 0.7250
# Epoch 35/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4186 - accuracy: 0.8086
# Epoch 00035: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4225 - accuracy: 0.8043 - val_loss: 0.5016 - val_accuracy: 0.7300
# Epoch 36/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4153 - accuracy: 0.8118
# Epoch 00036: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4157 - accuracy: 0.8105 - val_loss: 0.5048 - val_accuracy: 0.7250
# Epoch 37/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4245 - accuracy: 0.8040
# Epoch 00037: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4225 - accuracy: 0.8055 - val_loss: 0.4976 - val_accuracy: 0.7350
# Epoch 38/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4181 - accuracy: 0.8125
# Epoch 00038: val_accuracy did not improve from 0.80500
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4143 - accuracy: 0.8155 - val_loss: 0.5067 - val_accuracy: 0.7250
# Epoch 39/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4110 - accuracy: 0.8112
# Epoch 00039: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4083 - accuracy: 0.8130 - val_loss: 0.5031 - val_accuracy: 0.7250
# Epoch 40/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4197 - accuracy: 0.7995
# Epoch 00040: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4197 - accuracy: 0.8005 - val_loss: 0.5143 - val_accuracy: 0.7300
# Epoch 41/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4147 - accuracy: 0.8112
# Epoch 00041: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4125 - accuracy: 0.8124 - val_loss: 0.4978 - val_accuracy: 0.7350
# Epoch 42/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4145 - accuracy: 0.8118
# Epoch 00042: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4141 - accuracy: 0.8099 - val_loss: 0.5035 - val_accuracy: 0.7250
# Epoch 43/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4122 - accuracy: 0.8112
# Epoch 00043: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4157 - accuracy: 0.8093 - val_loss: 0.4995 - val_accuracy: 0.7300
# Epoch 44/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4111 - accuracy: 0.8118
# Epoch 00044: val_accuracy did not improve from 0.80500
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4092 - accuracy: 0.8136 - val_loss: 0.5043 - val_accuracy: 0.7250
# Epoch 45/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4137 - accuracy: 0.8118
# Epoch 00045: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4160 - accuracy: 0.8093 - val_loss: 0.5100 - val_accuracy: 0.7250
# Epoch 46/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4171 - accuracy: 0.8177
# Epoch 00046: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4202 - accuracy: 0.8149 - val_loss: 0.5020 - val_accuracy: 0.7250
# Epoch 47/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4070 - accuracy: 0.8216
# Epoch 00047: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4106 - accuracy: 0.8199 - val_loss: 0.4983 - val_accuracy: 0.7300
# Epoch 48/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4152 - accuracy: 0.8066
# Epoch 00048: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4176 - accuracy: 0.8068 - val_loss: 0.4999 - val_accuracy: 0.7250
# Epoch 49/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4186 - accuracy: 0.8079
# Epoch 00049: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4168 - accuracy: 0.8080 - val_loss: 0.5014 - val_accuracy: 0.7250
# Epoch 50/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4179 - accuracy: 0.8099
# Epoch 00050: val_accuracy did not improve from 0.80500
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4197 - accuracy: 0.8086 - val_loss: 0.5041 - val_accuracy: 0.7250

# %%
show_summary_stats(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# # Try model from blog
# https://github.com/priya-dwivedi/Music_Genre_Classification/blob/master/CRNN_model.ipynb

# %%
# Reload train and test
npzfile = np.load(CONVERTED_DIR/'train_arr.npz')
X_train = npzfile['X']
y_train = npzfile['y']

npzfile = np.load(CONVERTED_DIR/'valid_arr.npz')
X_valid = npzfile['X']
y_valid = npzfile['y']

# %%
y_train[:5]
# Out:
# array([0, 0, 1, 0, 1])

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 50
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.0004)
    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn_weights_best.h5', monitor='val_accuracy', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, 
                                          patience=10, min_delta=0.01, verbose=1)
    
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, 
                        callbacks=callbacks_list)

    return model, history

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, None, 128)]       0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_25 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_25 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_49 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_26 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_26 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_50 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_27 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_27 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_51 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 130
# _________________________________________________________________
# output_realtime (Activation) (None, 2)                 0
# =================================================================
# Total params: 133,130
# Trainable params: 132,794
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 1599 samples, validate on 200 samples
# Epoch 1/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.7963 - accuracy: 0.7415
# Epoch 00001: val_accuracy improved from -inf to 0.66000, saving model to ./models/crnn_weights_best.h5
# 1599/1599 [==============================] - 6s 4ms/sample - loss: 0.7913 - accuracy: 0.7455 - val_loss: 0.8846 - val_accuracy: 0.6600
# Epoch 2/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6892 - accuracy: 0.8210
# Epoch 00002: val_accuracy did not improve from 0.66000
# 1599/1599 [==============================] - 2s 2ms/sample - loss: 0.6885 - accuracy: 0.8193 - val_loss: 1.1713 - val_accuracy: 0.5500
# Epoch 3/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.6607 - accuracy: 0.8329
# Epoch 00003: val_accuracy improved from 0.66000 to 0.74000, saving model to ./models/crnn_weights_best.h5
# 1599/1599 [==============================] - 2s 2ms/sample - loss: 0.6602 - accuracy: 0.8330 - val_loss: 0.7749 - val_accuracy: 0.7400
# Epoch 4/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6461 - accuracy: 0.8444
# Epoch 00004: val_accuracy improved from 0.74000 to 0.81500, saving model to ./models/crnn_weights_best.h5
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6471 - accuracy: 0.8424 - val_loss: 0.6839 - val_accuracy: 0.8150
# Epoch 5/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.6285 - accuracy: 0.8412
# Epoch 00005: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6334 - accuracy: 0.8374 - val_loss: 0.7226 - val_accuracy: 0.7700
# Epoch 6/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.6243 - accuracy: 0.8361
# Epoch 00006: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6242 - accuracy: 0.8355 - val_loss: 0.7427 - val_accuracy: 0.7250
# Epoch 7/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6167 - accuracy: 0.8379
# Epoch 00007: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6140 - accuracy: 0.8393 - val_loss: 1.1681 - val_accuracy: 0.5400
# Epoch 8/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.6061 - accuracy: 0.8438
# Epoch 00008: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6054 - accuracy: 0.8443 - val_loss: 0.8992 - val_accuracy: 0.6650
# Epoch 9/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5889 - accuracy: 0.8489
# Epoch 00009: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5895 - accuracy: 0.8499 - val_loss: 0.9604 - val_accuracy: 0.5650
# Epoch 10/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5594 - accuracy: 0.8622
# Epoch 00010: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5608 - accuracy: 0.8605 - val_loss: 1.1835 - val_accuracy: 0.5650
# Epoch 11/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5521 - accuracy: 0.8616
# Epoch 00011: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5559 - accuracy: 0.8593 - val_loss: 0.7029 - val_accuracy: 0.8100
# Epoch 12/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5595 - accuracy: 0.8565
# Epoch 00012: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5606 - accuracy: 0.8562 - val_loss: 0.7090 - val_accuracy: 0.7550
# Epoch 13/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5598 - accuracy: 0.8578
# Epoch 00013: val_accuracy did not improve from 0.81500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5585 - accuracy: 0.8593 - val_loss: 0.6476 - val_accuracy: 0.8150
# Epoch 14/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5298 - accuracy: 0.8686
# Epoch 00014: val_accuracy improved from 0.81500 to 0.84500, saving model to ./models/crnn_weights_best.h5
# 1599/1599 [==============================] - 2s 2ms/sample - loss: 0.5274 - accuracy: 0.8699 - val_loss: 0.6088 - val_accuracy: 0.8450
# Epoch 15/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5296 - accuracy: 0.8559
# Epoch 00015: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5307 - accuracy: 0.8562 - val_loss: 0.6970 - val_accuracy: 0.7550
# Epoch 16/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5153 - accuracy: 0.8705
# Epoch 00016: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5176 - accuracy: 0.8705 - val_loss: 1.2553 - val_accuracy: 0.5550
# Epoch 17/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.5165 - accuracy: 0.8620
# Epoch 00017: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5151 - accuracy: 0.8637 - val_loss: 1.4718 - val_accuracy: 0.5000
# Epoch 18/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5001 - accuracy: 0.8744
# Epoch 00018: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4995 - accuracy: 0.8749 - val_loss: 1.4270 - val_accuracy: 0.5700
# Epoch 19/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.5053 - accuracy: 0.8622
# Epoch 00019: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.5034 - accuracy: 0.8630 - val_loss: 0.7105 - val_accuracy: 0.8050
# Epoch 20/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4830 - accuracy: 0.8833
# Epoch 00020: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4826 - accuracy: 0.8824 - val_loss: 0.8048 - val_accuracy: 0.7150
# Epoch 21/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4780 - accuracy: 0.8846
# Epoch 00021: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4777 - accuracy: 0.8837 - val_loss: 0.8079 - val_accuracy: 0.7850
# Epoch 22/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4618 - accuracy: 0.8820
# Epoch 00022: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4618 - accuracy: 0.8818 - val_loss: 0.7274 - val_accuracy: 0.7650
# Epoch 23/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4526 - accuracy: 0.8795
# Epoch 00023: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4523 - accuracy: 0.8806 - val_loss: 0.8377 - val_accuracy: 0.6850
# Epoch 24/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4494 - accuracy: 0.8861
# Epoch 00024: val_accuracy did not improve from 0.84500
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4507 - accuracy: 0.8856 - val_loss: 0.9692 - val_accuracy: 0.7350
# Epoch 25/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4387 - accuracy: 0.8865
# Epoch 00025: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4396 - accuracy: 0.8862 - val_loss: 1.0426 - val_accuracy: 0.6250
# Epoch 26/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4270 - accuracy: 0.8935
# Epoch 00026: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4280 - accuracy: 0.8924 - val_loss: 1.1041 - val_accuracy: 0.6150
# Epoch 27/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4349 - accuracy: 0.8852
# Epoch 00027: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4326 - accuracy: 0.8862 - val_loss: 1.2172 - val_accuracy: 0.5950
# Epoch 28/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4240 - accuracy: 0.9005
# Epoch 00028: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4228 - accuracy: 0.9012 - val_loss: 0.6282 - val_accuracy: 0.7750
# Epoch 29/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3917 - accuracy: 0.9076
# Epoch 00029: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3903 - accuracy: 0.9074 - val_loss: 1.1339 - val_accuracy: 0.6350
# Epoch 30/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3962 - accuracy: 0.9037
# Epoch 00030: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3984 - accuracy: 0.9031 - val_loss: 0.7342 - val_accuracy: 0.7850
# Epoch 31/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.9114
# Epoch 00031: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3834 - accuracy: 0.9093 - val_loss: 0.7259 - val_accuracy: 0.7450
# Epoch 32/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4010 - accuracy: 0.9011
# Epoch 00032: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4027 - accuracy: 0.8993 - val_loss: 0.7322 - val_accuracy: 0.7700
# Epoch 33/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.4058 - accuracy: 0.9005
# Epoch 00033: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.4069 - accuracy: 0.8993 - val_loss: 0.7611 - val_accuracy: 0.6850
# Epoch 34/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3646 - accuracy: 0.9177
# Epoch 00034: val_accuracy did not improve from 0.84500
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3633 - accuracy: 0.9181 - val_loss: 0.7297 - val_accuracy: 0.7700
# Epoch 35/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3540 - accuracy: 0.9126
# Epoch 00035: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3540 - accuracy: 0.9131 - val_loss: 0.7214 - val_accuracy: 0.8000
# Epoch 36/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3613 - accuracy: 0.9152
# Epoch 00036: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3620 - accuracy: 0.9156 - val_loss: 0.8827 - val_accuracy: 0.7650
# Epoch 37/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3482 - accuracy: 0.9219
# Epoch 00037: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 2ms/sample - loss: 0.3535 - accuracy: 0.9187 - val_loss: 0.7896 - val_accuracy: 0.8050
# Epoch 38/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3513 - accuracy: 0.9193
# Epoch 00038: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3502 - accuracy: 0.9193 - val_loss: 0.8703 - val_accuracy: 0.7650
# Epoch 39/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3317 - accuracy: 0.9303
# Epoch 00039: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3322 - accuracy: 0.9300 - val_loss: 0.7415 - val_accuracy: 0.8050
# Epoch 40/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3148 - accuracy: 0.9355
# Epoch 00040: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3156 - accuracy: 0.9343 - val_loss: 0.7714 - val_accuracy: 0.8050
# Epoch 41/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3381 - accuracy: 0.9228
# Epoch 00041: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3414 - accuracy: 0.9212 - val_loss: 0.9880 - val_accuracy: 0.7350
# Epoch 42/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3271 - accuracy: 0.9273
# Epoch 00042: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3288 - accuracy: 0.9275 - val_loss: 0.9284 - val_accuracy: 0.7150
# Epoch 43/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3345 - accuracy: 0.9190
# Epoch 00043: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 2ms/sample - loss: 0.3321 - accuracy: 0.9206 - val_loss: 1.3801 - val_accuracy: 0.6400
# Epoch 44/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3299 - accuracy: 0.9180
# Epoch 00044: val_accuracy did not improve from 0.84500
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3282 - accuracy: 0.9193 - val_loss: 1.0496 - val_accuracy: 0.7150
# Epoch 45/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3117 - accuracy: 0.9349
# Epoch 00045: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3101 - accuracy: 0.9356 - val_loss: 0.9839 - val_accuracy: 0.7400
# Epoch 46/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3025 - accuracy: 0.9381
# Epoch 00046: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3048 - accuracy: 0.9368 - val_loss: 1.0932 - val_accuracy: 0.7450
# Epoch 47/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.2937 - accuracy: 0.9395
# Epoch 00047: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 2ms/sample - loss: 0.2990 - accuracy: 0.9362 - val_loss: 1.2743 - val_accuracy: 0.7050
# Epoch 48/50
# 1568/1599 [============================>.] - ETA: 0s - loss: 0.3062 - accuracy: 0.9362
# Epoch 00048: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3046 - accuracy: 0.9368 - val_loss: 1.0309 - val_accuracy: 0.7500
# Epoch 49/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.3054 - accuracy: 0.9349
# Epoch 00049: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.3028 - accuracy: 0.9350 - val_loss: 0.8549 - val_accuracy: 0.7850
# Epoch 50/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.2975 - accuracy: 0.9408
# Epoch 00050: val_accuracy did not improve from 0.84500
# 1599/1599 [==============================] - 3s 2ms/sample - loss: 0.3018 - accuracy: 0.9393 - val_loss: 0.8076 - val_accuracy: 0.7900

# %%
show_summary_stats(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
