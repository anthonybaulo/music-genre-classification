# %%
import os
import numpy as np
import librosa
import librosa.display
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from tensorflow.keras.layers import MaxPooling2D, Flatten, Conv1D, \
                                    Conv2D, BatchNormalization, MaxPooling1D, \
                                    GlobalAveragePooling2D
from tensorflow.keras.layers import Lambda, ELU
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # Rock vs Instrumental

# %%
META_DIR = Path('../data/fma_metadata')
AUDIO_DIR = Path('../data/fma_small')
CONVERTED_DIR = Path('../data/converted/rock_inst')

# %%
def show_summary_stats(history, dpi=100):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.figure(figsize=(4,3), dpi=dpi)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()

    # Summarize history for loss
    plt.figure(figsize=(4,3), dpi=dpi)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()

# %%
genre_dict = {'Rock': 0, 'Instrumental': 1}

reverse_map = {v: k for k, v in genre_dict.items()}
print(reverse_map)
# Out:
# {0: 'Rock', 1: 'Instrumental'}

# %%
npzfile = np.load(CONVERTED_DIR/'train_arr.npz')
X_train = npzfile['X']
y_train = npzfile['y']
print(X_train.shape, y_train.shape)
# Out:
# (1599, 640, 128) (1599,)

# %%
npzfile = np.load(CONVERTED_DIR/'valid_arr.npz')
X_valid = npzfile['X']
y_valid = npzfile['y']
print(X_valid.shape, y_valid.shape)
# Out:
# (200, 640, 128) (200,)

# %%
# Add dimension for single channel for Conv2D
X_train = X_train[...,None] / -80
X_valid = X_valid[...,None] / -80

# %%
y_train = to_categorical(y_train)
y_valid = to_categorical(y_valid)

# %%
# Build model
model = Sequential()

model.add(Conv2D(32, (5, 5), input_shape = (640, 128, 1), 
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (1, 1), activation='relu'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))

model.add(Dense(units = 64, activation = 'relu'))
model.add(Dropout(0.3))

model.add(Dense(units = 2, activation = 'softmax'))

opt = Adam(lr=0.0005)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 640, 128, 32)      832
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 320, 64, 32)       0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 320, 64, 32)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 318, 62, 64)       18496
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 318, 62, 128)      8320
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 128)               0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 36,034
# Trainable params: 36,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_callback = ModelCheckpoint('../models/model2_best.h5', monitor='val_accuracy', verbose=1,
                                      save_best_only=True, mode='max')

reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, 
                                      patience=6, min_delta=0.01, verbose=1)

callbacks_list = [checkpoint_callback, reducelr_callback]

# %%
history = model.fit(X_train, y_train, batch_size=128, epochs=50,
                    validation_data=(X_valid, y_valid), verbose=1, 
                    callbacks=callbacks_list)
# Out:
# Train on 1599 samples, validate on 200 samples
# Epoch 1/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6890 - accuracy: 0.4922
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 17s 11ms/sample - loss: 0.6894 - accuracy: 0.4891 - val_loss: 0.6893 - val_accuracy: 0.5000
# Epoch 2/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6762 - accuracy: 0.5039
# Epoch 00002: val_accuracy did not improve from 0.50000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6765 - accuracy: 0.5022 - val_loss: 0.6836 - val_accuracy: 0.5000
# Epoch 3/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6695 - accuracy: 0.5078
# Epoch 00003: val_accuracy improved from 0.50000 to 0.50500, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6693 - accuracy: 0.5078 - val_loss: 0.6763 - val_accuracy: 0.5050
# Epoch 4/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6560 - accuracy: 0.5794
# Epoch 00004: val_accuracy improved from 0.50500 to 0.52000, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6553 - accuracy: 0.5785 - val_loss: 0.6632 - val_accuracy: 0.5200
# Epoch 5/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6272 - accuracy: 0.6549
# Epoch 00005: val_accuracy improved from 0.52000 to 0.73500, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.6258 - accuracy: 0.6560 - val_loss: 0.6331 - val_accuracy: 0.7350
# Epoch 6/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.5717 - accuracy: 0.7624
# Epoch 00006: val_accuracy did not improve from 0.73500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.5716 - accuracy: 0.7617 - val_loss: 0.6099 - val_accuracy: 0.7000
# Epoch 7/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.5156 - accuracy: 0.7793
# Epoch 00007: val_accuracy did not improve from 0.73500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.5129 - accuracy: 0.7799 - val_loss: 0.5697 - val_accuracy: 0.7100
# Epoch 8/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4674 - accuracy: 0.7910
# Epoch 00008: val_accuracy improved from 0.73500 to 0.78000, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4664 - accuracy: 0.7924 - val_loss: 0.5383 - val_accuracy: 0.7800
# Epoch 9/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4618 - accuracy: 0.7910
# Epoch 00009: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4636 - accuracy: 0.7892 - val_loss: 0.5497 - val_accuracy: 0.7250
# Epoch 10/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4523 - accuracy: 0.8060
# Epoch 00010: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4491 - accuracy: 0.8074 - val_loss: 0.5747 - val_accuracy: 0.6950
# Epoch 11/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4408 - accuracy: 0.8053
# Epoch 00011: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4377 - accuracy: 0.8068 - val_loss: 0.5444 - val_accuracy: 0.7300
# Epoch 12/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4301 - accuracy: 0.8086
# Epoch 00012: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4314 - accuracy: 0.8086 - val_loss: 0.5273 - val_accuracy: 0.7450
# Epoch 13/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4535 - accuracy: 0.7923
# Epoch 00013: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4538 - accuracy: 0.7924 - val_loss: 0.7145 - val_accuracy: 0.6150
# Epoch 14/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4516 - accuracy: 0.7910
# Epoch 00014: val_accuracy did not improve from 0.78000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4490 - accuracy: 0.7942 - val_loss: 0.5322 - val_accuracy: 0.7300
# Epoch 15/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4418 - accuracy: 0.7969
# Epoch 00015: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4419 - accuracy: 0.7961 - val_loss: 0.5288 - val_accuracy: 0.7250
# Epoch 16/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4368 - accuracy: 0.8066
# Epoch 00016: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4359 - accuracy: 0.8068 - val_loss: 0.6054 - val_accuracy: 0.6800
# Epoch 17/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4380 - accuracy: 0.8027
# Epoch 00017: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4338 - accuracy: 0.8055 - val_loss: 0.5832 - val_accuracy: 0.6950
# Epoch 18/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4307 - accuracy: 0.8053
# Epoch 00018: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4257 - accuracy: 0.8093 - val_loss: 0.5740 - val_accuracy: 0.6950
# Epoch 19/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4307 - accuracy: 0.8027
# Epoch 00019: val_accuracy did not improve from 0.78000
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4273 - accuracy: 0.8061 - val_loss: 0.5121 - val_accuracy: 0.7400
# Epoch 20/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4275 - accuracy: 0.8047
# Epoch 00020: val_accuracy improved from 0.78000 to 0.80500, saving model to ../models/model2_best.h5
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4257 - accuracy: 0.8043 - val_loss: 0.4949 - val_accuracy: 0.8050
# Epoch 21/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4148 - accuracy: 0.8060
# Epoch 00021: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 12s 8ms/sample - loss: 0.4215 - accuracy: 0.8043 - val_loss: 0.5198 - val_accuracy: 0.7250
# Epoch 22/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4248 - accuracy: 0.8053
# Epoch 00022: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4259 - accuracy: 0.8036 - val_loss: 0.6016 - val_accuracy: 0.6800
# Epoch 23/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4323 - accuracy: 0.8125
# Epoch 00023: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4323 - accuracy: 0.8124 - val_loss: 0.5603 - val_accuracy: 0.7200
# Epoch 24/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4301 - accuracy: 0.8073
# Epoch 00024: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.
val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4160 - accuracy: 0.8093 - val_loss: 0.5100 - val_accuracy: 0.7250
# Epoch 46/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4171 - accuracy: 0.8177
# Epoch 00046: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4202 - accuracy: 0.8149 - val_loss: 0.5020 - val_accuracy: 0.7250
# Epoch 47/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4070 - accuracy: 0.8216
# Epoch 00047: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4106 - accuracy: 0.8199 - val_loss: 0.4983 - val_accuracy: 0.7300
# Epoch 48/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4152 - accuracy: 0.8066
# Epoch 00048: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4176 - accuracy: 0.8068 - val_loss: 0.4999 - val_accuracy: 0.7250
# Epoch 49/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4186 - accuracy: 0.8079
# Epoch 00049: val_accuracy did not improve from 0.80500
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4168 - accuracy: 0.8080 - val_loss: 0.5014 - val_accuracy: 0.7250
# Epoch 50/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4179 - accuracy: 0.8099
# Epoch 00050: val_accuracy did not improve from 0.80500
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1599/1599 [==============================] - 13s 8ms/sample - loss: 0.4197 - accuracy: 0.8086 - val_loss: 0.5041 - val_accuracy: 0.7250

# %%
show_summary_stats(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# # Model from blog
# https://github.com/priya-dwivedi/Music_Genre_Classification/blob/master/CRNN_model.ipynb

# %%
# Reload train and test
npzfile = np.load(CONVERTED_DIR/'train_arr.npz')
X_train = npzfile['X']
y_train = npzfile['y']

npzfile = np.load(CONVERTED_DIR/'valid_arr.npz')
X_valid = npzfile['X']
y_valid = npzfile['y']

# %%
# Normalize
X_train = X_train / -80
X_valid = X_valid / -80

# %%
y_train = to_categorical(y_train)
y_valid = to_categorical(y_valid)

# %%
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 128
LSTM_COUNT = 96
EPOCH_COUNT = 50
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.0004)
    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('../models/crnn_weights_best.h5', monitor='val_accuracy', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, 
                                          patience=10, min_delta=0.01, verbose=1)
    
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, 
                        callbacks=callbacks_list)

    return model, history

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, None, 128)]       0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_9 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_10 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_10 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_11 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_11 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 130
# _________________________________________________________________
# output_realtime (Activation) (None, 2)                 0
# =================================================================
# Total params: 133,130
# Trainable params: 132,794
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 1599 samples, validate on 200 samples
# Epoch 1/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.8325 - accuracy: 0.7155
# Epoch 00001: val_accuracy improved from -inf to 0.51500, saving model to ../models/crnn_weights_best.h5
# 1599/1599 [==============================] - 5s 3ms/sample - loss: 0.8349 - accuracy: 0.7186 - val_loss: 1.0468 - val_accuracy: 0.5150
# Epoch 2/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.7362 - accuracy: 0.8086
# Epoch 00002: val_accuracy improved from 0.51500 to 0.71500, saving model to ../models/crnn_weights_best.h5
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.7406 - accuracy: 0.8061 - val_loss: 0.8067 - val_accuracy: 0.7150
# Epoch 3/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.7052 - accuracy: 0.7969
# Epoch 00003: val_accuracy did not improve from 0.71500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.7089 - accuracy: 0.7955 - val_loss: 0.8111 - val_accuracy: 0.7100
# Epoch 4/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6895 - accuracy: 0.8105
# Epoch 00004: val_accuracy improved from 0.71500 to 0.79500, saving model to ../models/crnn_weights_best.h5
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6852 - accuracy: 0.8136 - val_loss: 0.7316 - val_accuracy: 0.7950
# Epoch 5/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6639 - accuracy: 0.8359
# Epoch 00005: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6598 - accuracy: 0.8380 - val_loss: 0.8742 - val_accuracy: 0.7000
# Epoch 6/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6467 - accuracy: 0.8385
# Epoch 00006: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6520 - accuracy: 0.8361 - val_loss: 1.5101 - val_accuracy: 0.5350
# Epoch 7/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6321 - accuracy: 0.8418
# Epoch 00007: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6352 - accuracy: 0.8405 - val_loss: 0.7551 - val_accuracy: 0.7800
# Epoch 8/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6422 - accuracy: 0.8424
# Epoch 00008: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6386 - accuracy: 0.8455 - val_loss: 0.7789 - val_accuracy: 0.7650
# Epoch 9/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.6186 - accuracy: 0.8555
# Epoch 00009: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.6189 - accuracy: 0.8562 - val_loss: 0.6994 - val_accuracy: 0.7900
# Epoch 10/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.
50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4615 - accuracy: 0.9173
# Epoch 00031: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4630 - accuracy: 0.9181 - val_loss: 1.0377 - val_accuracy: 0.6700
# Epoch 32/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4538 - accuracy: 0.9180
# Epoch 00032: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4617 - accuracy: 0.9149 - val_loss: 0.8953 - val_accuracy: 0.6950
# Epoch 33/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4658 - accuracy: 0.9121
# Epoch 00033: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4616 - accuracy: 0.9131 - val_loss: 1.0834 - val_accuracy: 0.6550
# Epoch 34/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4602 - accuracy: 0.9134
# Epoch 00034: val_accuracy did not improve from 0.79500
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4593 - accuracy: 0.9149 - val_loss: 0.9201 - val_accuracy: 0.7250
# Epoch 35/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4493 - accuracy: 0.9154
# Epoch 00035: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4513 - accuracy: 0.9137 - val_loss: 0.8706 - val_accuracy: 0.6850
# Epoch 36/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4405 - accuracy: 0.9173
# Epoch 00036: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4410 - accuracy: 0.9181 - val_loss: 0.8468 - val_accuracy: 0.7600
# Epoch 37/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4472 - accuracy: 0.9245
# Epoch 00037: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4487 - accuracy: 0.9237 - val_loss: 0.8743 - val_accuracy: 0.7150
# Epoch 38/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4460 - accuracy: 0.9232
# Epoch 00038: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4427 - accuracy: 0.9237 - val_loss: 0.8845 - val_accuracy: 0.7050
# Epoch 39/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4411 - accuracy: 0.9258
# Epoch 00039: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4407 - accuracy: 0.9256 - val_loss: 0.9041 - val_accuracy: 0.7300
# Epoch 40/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4406 - accuracy: 0.9232
# Epoch 00040: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4385 - accuracy: 0.9243 - val_loss: 0.8874 - val_accuracy: 0.7050
# Epoch 41/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4323 - accuracy: 0.9310
# Epoch 00041: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4380 - accuracy: 0.9281 - val_loss: 0.8991 - val_accuracy: 0.7050
# Epoch 42/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4339 - accuracy: 0.9290
# Epoch 00042: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4346 - accuracy: 0.9281 - val_loss: 0.9189 - val_accuracy: 0.7000
# Epoch 43/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4395 - accuracy: 0.9193
# Epoch 00043: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4433 - accuracy: 0.9174 - val_loss: 0.8844 - val_accuracy: 0.7250
# Epoch 44/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4324 - accuracy: 0.9238
# Epoch 00044: val_accuracy did not improve from 0.79500
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4340 - accuracy: 0.9231 - val_loss: 0.8908 - val_accuracy: 0.7000
# Epoch 45/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4323 - accuracy: 0.9277
# Epoch 00045: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4295 - accuracy: 0.9281 - val_loss: 0.8963 - val_accuracy: 0.6800
# Epoch 46/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4367 - accuracy: 0.9219
# Epoch 00046: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4345 - accuracy: 0.9231 - val_loss: 0.9374 - val_accuracy: 0.7100
# Epoch 47/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4361 - accuracy: 0.9212
# Epoch 00047: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4308 - accuracy: 0.9237 - val_loss: 0.9112 - val_accuracy: 0.7150
# Epoch 48/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4241 - accuracy: 0.9355
# Epoch 00048: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4281 - accuracy: 0.9325 - val_loss: 0.9110 - val_accuracy: 0.7200
# Epoch 49/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4307 - accuracy: 0.9310
# Epoch 00049: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4311 - accuracy: 0.9300 - val_loss: 0.9715 - val_accuracy: 0.6950
# Epoch 50/50
# 1536/1599 [===========================>..] - ETA: 0s - loss: 0.4337 - accuracy: 0.9310
# Epoch 00050: val_accuracy did not improve from 0.79500
# 1599/1599 [==============================] - 2s 1ms/sample - loss: 0.4306 - accuracy: 0.9318 - val_loss: 0.9452 - val_accuracy: 0.7150

# %%
show_summary_stats(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
